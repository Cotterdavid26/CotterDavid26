# %%
import pandas as pd
df = pd.read_csv('Direct_Marketing_campaign.csv')

# %%
# Sample the dataset to view what is in it
df.head(20)
# Out:
#     Age           Job Marital Status  Education Credit  Balance Housing Loan  \
# 0    58    management        married   tertiary     no     2143          yes
# 1    44    technician         single  secondary     no       29          yes
# 2    33  entrepreneur        married  secondary     no        2          yes
# 3    47   blue-collar        married    unknown     no     1506          yes
# 4    33       unknown         single    unknown     no        1           no
# 5    35    management        married   tertiary     no      231          yes
# 6    28    management         single   tertiary     no      447          yes
# 7    42  entrepreneur       divorced   tertiary    yes        2          yes
# 8    58       retired        married    primary     no      121          yes
# 9    43    technician         single  secondary     no      593          yes
# 10   41        admin.       divorced  secondary     no      270          yes
# ...

# %%
#check how many rows are in dataframe and for any null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    45211 non-null  int64
#  1   Job                    45211 non-null  object
#  2   Marital Status         45211 non-null  object
#  3   Education              45211 non-null  object
#  4   Credit                 45211 non-null  object
#  5   Balance                45211 non-null  int64
#  6   Housing Loan           45211 non-null  object
#  7   Personal Loan          45211 non-null  object
#  8   Contact type           45211 non-null  object
#  9   Last Contact Day       45211 non-null  int64
#  10  Last Contact Month     45211 non-null  object
#  11  Last Contact Duration  45211 non-null  int64
#  12  Campaign Freq          45211 non-null  int64
#  13  Lag in days            45211 non-null  int64
# ...

# %%
# explore the types of jobs the customer base has 
df['Job'].value_counts()
# Out:
# Job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64

# %%
# see how many people subscribed to the latest campaign
df['Subscription'].value_counts()
# Out:
# Subscription
# 1    39922
# 2     5289
# Name: count, dtype: int64

# %%
#make a dataframe of just subcribed customers 
dfsub = df[df['Subscription']==2]

# %%
#dataframe of no subscribers 
dfnosub = df[df['Subscription']==1]

# %%
#view Sub dataframe
dfsub
# Out:
#        Age         Job Marital Status  Education Credit  Balance Housing Loan  \
# 83      59      admin.        married  secondary     no     2343          yes
# 86      56      admin.        married  secondary     no       45           no
# 87      41  technician        married  secondary     no     1270          yes
# 129     55    services        married  secondary     no     2476          yes
# 168     54      admin.        married   tertiary     no      184           no
# ...    ...         ...            ...        ...    ...      ...          ...
# 45204   73     retired        married  secondary     no     2850           no
# 45205   25  technician         single  secondary     no      505           no
# 45206   51  technician        married   tertiary     no      825           no
# 45207   71     retired       divorced    primary     no     1729           no
# 45208   72     retired        married  secondary     no     5715           no
#
# ...

# %%
#check the type of jobs those that subscribed had
dfsub['Job'].value_counts()
# Out:
# Job
# management       1301
# technician        840
# blue-collar       708
# admin.            631
# retired           516
# services          369
# student           269
# unemployed        202
# self-employed     187
# entrepreneur      123
# housemaid         109
# unknown            34
# Name: count, dtype: int64

# %%
#check what kind of jobs those that didn't subscribe have
dfnosub['Job'].value_counts()
# Out:
# Job
# blue-collar      9024
# management       8157
# technician       6757
# admin.           4540
# services         3785
# retired          1748
# self-employed    1392
# entrepreneur     1364
# housemaid        1131
# unemployed       1101
# student           669
# unknown           254
# Name: count, dtype: int64

# %%
#sample no sub dataframe
dfnosub
# Out:
#        Age           Job Marital Status  Education Credit  Balance  \
# 0       58    management        married   tertiary     no     2143
# 1       44    technician         single  secondary     no       29
# 2       33  entrepreneur        married  secondary     no        2
# 3       47   blue-collar        married    unknown     no     1506
# 4       33       unknown         single    unknown     no        1
# ...    ...           ...            ...        ...    ...      ...
# 45194   59    management        married   tertiary     no      138
# 45198   37    management        married   tertiary     no     1428
# 45199   34   blue-collar         single  secondary     no     1475
# 45209   57   blue-collar        married  secondary     no      668
# 45210   37  entrepreneur        married  secondary     no     2971
#
#       Housing Loan Personal Loan Contact type  Last Contact Day  \
# 0              yes            no      unknown                 5
# ...

# %%
#check to see if any corralation between columns
dfsub.corr(numeric_only=True)
# Out:
#                             Age   Balance  Last Contact Day  \
# Age                    1.000000  0.122228          0.007198
# Balance                0.122228  1.000000          0.013673
# Last Contact Day       0.007198  0.013673          1.000000
# Last Contact Duration -0.027995 -0.036677          0.039467
# Campaign Freq         -0.020674  0.001535          0.078702
# Lag in days            0.020108  0.010746         -0.025849
# Previous Freq          0.033676  0.020790         -0.039869
# Subscription                NaN       NaN               NaN
#
#                        Last Contact Duration  Campaign Freq  Lag in days  \
# Age                                -0.027995      -0.020674     0.020108
# Balance                            -0.036677       0.001535     0.010746
# Last Contact Day                    0.039467       0.078702    -0.025849
# Last Contact Duration               1.000000       0.160473    -0.162737
# ...

# %%
#check the age of those most likely to subscribe
dfsub['Age'].value_counts().head(50)
# Out:
# Age
# 32    221
# 30    217
# 33    210
# 35    209
# 31    206
# 34    198
# 36    195
# 29    171
# 37    170
# 28    162
# 38    144
# 39    143
# 27    141
# 26    134
# 41    120
# 46    118
# 40    116
# 25    113
# 47    113
# 42    111
# 45    106
# 43    103
# 49    101
# 60     98
# 44     93
# 59     88
# 53     85
# 52     85
# 54     84
# 48     82
# 57     78
# 51     77
# 55     76
# 58     72
# 50     72
# 24     68
# 56     68
# 61     57
# 23     44
# 22     40
# 62     39
# 64     35
# 63     30
# 71     25
# 66     24
# 72     24
# 73     24
# 67     23
# 77     22
# 21     22
# Name: count, dtype: int64

# %%
# categories customers based on age groups
def age_buckets(x): 
    if x < 30: 
        return '18-29' 
    elif x < 40: 
        return '30-39' 
    elif x < 50: 
        return '40-49' 
    elif x < 60: 
        return '50-59' 
    elif x < 70: 
        return '60-69' 
    elif x < 80: 
        return '70-79'
    elif x < 90:
        return '80-89'
    elif x >= 90:
        return 'Over 90'
    else: return 'other'

# %%
#add new column that includes age range in dataframe
dfsub['Age Range'] = dfsub.Age.apply(age_buckets)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14588\2295505471.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfsub['Age Range'] = dfsub.Age.apply(age_buckets)

# %%
#preview dataframe
dfsub
# Out:
#        Age         Job Marital Status  Education Credit  Balance Housing Loan  \
# 83      59      admin.        married  secondary     no     2343          yes
# 86      56      admin.        married  secondary     no       45           no
# 87      41  technician        married  secondary     no     1270          yes
# 129     55    services        married  secondary     no     2476          yes
# 168     54      admin.        married   tertiary     no      184           no
# ...    ...         ...            ...        ...    ...      ...          ...
# 45204   73     retired        married  secondary     no     2850           no
# 45205   25  technician         single  secondary     no      505           no
# 45206   51  technician        married   tertiary     no      825           no
# 45207   71     retired       divorced    primary     no     1729           no
# 45208   72     retired        married  secondary     no     5715           no
#
# ...

# %%
#check info on new dataframe
dfsub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5289 entries, 83 to 45208
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    5289 non-null   int64
#  1   Job                    5289 non-null   object
#  2   Marital Status         5289 non-null   object
#  3   Education              5289 non-null   object
#  4   Credit                 5289 non-null   object
#  5   Balance                5289 non-null   int64
#  6   Housing Loan           5289 non-null   object
#  7   Personal Loan          5289 non-null   object
#  8   Contact type           5289 non-null   object
#  9   Last Contact Day       5289 non-null   int64
#  10  Last Contact Month     5289 non-null   object
#  11  Last Contact Duration  5289 non-null   int64
#  12  Campaign Freq          5289 non-null   int64
#  13  Lag in days            5289 non-null   int64
# ...

# %%
#complete a value count on age ranges to see which ones subscribed most
dfsub['Age Range'].value_counts()
# Out:
# Age Range
# 30-39      1913
# 40-49      1063
# 18-29       928
# 50-59       785
# 60-69       365
# 70-79       180
# 80-89        48
# Over 90       7
# Name: count, dtype: int64

# %%
# create new dataframe with just age and job type 
dfsub2 = dfsub[['Age Range','Job']]

# %%
#reset the index
dfsub2.reset_index(drop=True)
# Out:
#      Age Range         Job
# 0        50-59      admin.
# 1        50-59      admin.
# 2        40-49  technician
# 3        50-59    services
# 4        50-59      admin.
# ...        ...         ...
# 5284     70-79     retired
# 5285     18-29  technician
# 5286     50-59  technician
# 5287     70-79     retired
# 5288     70-79     retired
#
# [5289 rows x 2 columns]

# %%
df
# Out:
#        Age           Job Marital Status  Education Credit  Balance  \
# 0       58    management        married   tertiary     no     2143
# 1       44    technician         single  secondary     no       29
# 2       33  entrepreneur        married  secondary     no        2
# 3       47   blue-collar        married    unknown     no     1506
# 4       33       unknown         single    unknown     no        1
# ...    ...           ...            ...        ...    ...      ...
# 45206   51    technician        married   tertiary     no      825
# 45207   71       retired       divorced    primary     no     1729
# 45208   72       retired        married  secondary     no     5715
# 45209   57   blue-collar        married  secondary     no      668
# 45210   37  entrepreneur        married  secondary     no     2971
#
#       Housing Loan Personal Loan Contact type  Last Contact Day  \
# 0              yes            no      unknown                 5
# ...

# %%
df['Age Range'] = df.Age.apply(age_buckets)

# %%
df['Subscription'].value_counts()
# Out:
# Subscription
# 1    39922
# 2     5289
# Name: count, dtype: int64

# %%
df['Age Range'].value_counts()
# Out:
# Age Range
# 30-39      18089
# 40-49      11655
# 50-59       8410
# 18-29       5273
# 60-69       1230
# 70-79        424
# 80-89        121
# Over 90        9
# Name: count, dtype: int64

# %%
#group by age range and subscription status so have two rows for each age range 

# convert subscription into a boolean 1(No) 2 (Yes)
df['Subscription1'] = df['Subscription'].map({1:False, 2: True})

# Group by AgeGroup and Subscribed, then count the occurrences
df_age = df.groupby(['Age Range', 'Subscription1']).size().reset_index(name ='Count')

df_age['Subscription1'] = df_age['Subscription1'].map({False: 'No', True: 'Yes'})

# Pivot the DataFrame to have Age range as rows and Subscribed status as columns
df_age1 = df_age.pivot(index='Age Range', columns='Subscription1', values='Count').reset_index()

# %%
#Preview pivoted Dataframe
df_age1
# Out:
# Subscription1 Age Range     No   Yes
# 0                 18-29   4345   928
# 1                 30-39  16176  1913
# 2                 40-49  10592  1063
# 3                 50-59   7625   785
# 4                 60-69    865   365
# 5                 70-79    244   180
# 6                 80-89     73    48
# 7               Over 90      2     7

# %%
df_age
# Out:
#    Age Range Subscription1  Count
# 0      18-29            No   4345
# 1      18-29           Yes    928
# 2      30-39            No  16176
# 3      30-39           Yes   1913
# 4      40-49            No  10592
# 5      40-49           Yes   1063
# 6      50-59            No   7625
# 7      50-59           Yes    785
# 8      60-69            No    865
# 9      60-69           Yes    365
# 10     70-79            No    244
# 11     70-79           Yes    180
# 12     80-89            No     73
# 13     80-89           Yes     48
# 14   Over 90            No      2
# 15   Over 90           Yes      7

# %%
# Group by Age and Job type
df_agejob = df.groupby(['Age Range', 'Job', 'Subscription1']).size().reset_index(name='Count')

# %%
#Preview pivoted Dataframe
df_agejob
# Out:
#     Age Range           Job  Subscription1  Count
# 0       18-29        admin.          False    640
# 1       18-29        admin.           True    111
# 2       18-29   blue-collar          False   1003
# 3       18-29   blue-collar           True    130
# 4       18-29  entrepreneur          False     88
# ..        ...           ...            ...    ...
# 135     80-89       retired          False     64
# 136     80-89       retired           True     45
# 137     80-89       unknown          False      1
# 138   Over 90       retired          False      2
# 139   Over 90       retired           True      7
#
# [140 rows x 4 columns]

# %%
#Segment into job type 
df_job = df.groupby(['Job', 'Subscription1']).size().reset_index(name='Count')

df_job['Subscription1'] = df_job['Subscription1'].map({False: 'No', True: 'Yes'})

# Pivot the DataFrame to have Job as rows and Subscribed status as columns
df_job = df_job.pivot(index='Job', columns='Subscription1', values='Count').reset_index()

# %%
#Preview pivoted Dataframe
df_job
# Out:
# Subscription1            Job    No   Yes
# 0                     admin.  4540   631
# 1                blue-collar  9024   708
# 2               entrepreneur  1364   123
# 3                  housemaid  1131   109
# 4                 management  8157  1301
# 5                    retired  1748   516
# 6              self-employed  1392   187
# 7                   services  3785   369
# 8                    student   669   269
# 9                 technician  6757   840
# 10                unemployed  1101   202
# 11                   unknown   254    34

# %%
#investigate whether it is worth segmenting by average account balance
df['Balance'].value_counts()
# Out:
# Balance
#  0        3514
#  1         195
#  2         156
#  4         139
#  3         134
#           ...
# -381         1
#  4617        1
#  20584       1
#  4358        1
#  16353       1
# Name: count, Length: 7168, dtype: int64

# %%
#checking max balance
df['Balance'].max()
# Out:
# 102127

# %%
#checking min Balance
df['Balance'].min()
# Out:
# -8019

# %%
# categories customers based on balance
def balance_buckets(x):
    if x < -5000:
        return 'below - 5000'
    elif x < 0:
        return '0 - -4999'
    elif x < 5000: 
        return '0 - 4999' 
    elif x < 10000: 
        return '5000 - 9999' 
    elif x < 15000: 
        return '10000 - 14999' 
    elif x < 20000: 
        return '15000 - 19999' 
    elif x < 25000: 
        return '20000 - 24999' 
    elif x < 30000: 
        return '25000 - 29999'
    elif x < 35000:
        return '30000 - 34999'
    else: 
        return 'Over 35000'

# %%
df
# Out:
#        Age           Job Marital Status  Education Credit  Balance  \
# 0       58    management        married   tertiary     no     2143
# 1       44    technician         single  secondary     no       29
# 2       33  entrepreneur        married  secondary     no        2
# 3       47   blue-collar        married    unknown     no     1506
# 4       33       unknown         single    unknown     no        1
# ...    ...           ...            ...        ...    ...      ...
# 45206   51    technician        married   tertiary     no      825
# 45207   71       retired       divorced    primary     no     1729
# 45208   72       retired        married  secondary     no     5715
# 45209   57   blue-collar        married  secondary     no      668
# 45210   37  entrepreneur        married  secondary     no     2971
#
#       Housing Loan Personal Loan Contact type  Last Contact Day  \
# 0              yes            no      unknown                 5
# ...

# %%
#check that no nil outcomes happened
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    45211 non-null  int64
#  1   Job                    45211 non-null  object
#  2   Marital Status         45211 non-null  object
#  3   Education              45211 non-null  object
#  4   Credit                 45211 non-null  object
#  5   Balance                45211 non-null  int64
#  6   Housing Loan           45211 non-null  object
#  7   Personal Loan          45211 non-null  object
#  8   Contact type           45211 non-null  object
#  9   Last Contact Day       45211 non-null  int64
#  10  Last Contact Month     45211 non-null  object
#  11  Last Contact Duration  45211 non-null  int64
#  12  Campaign Freq          45211 non-null  int64
#  13  Lag in days            45211 non-null  int64
# ...

# %%
#check negative balances categories correctly
df4 = df[df['Balance'] < 0]

# %%
#check how many customer have balance under £0
df4.head(50)
# Out:
#      Age            Job Marital Status  Education Credit  Balance  \
# 25    44         admin.        married  secondary     no     -372
# 28    46     management         single  secondary     no     -246
# 36    25    blue-collar        married  secondary     no       -7
# 37    53     technician        married  secondary     no       -3
# 45    36         admin.         single    primary     no     -171
# 46    58  self-employed        married   tertiary     no     -364
# 51    48     management       divorced   tertiary     no     -244
# 53    42         admin.         single  secondary     no      -76
# 54    24     technician         single  secondary     no     -103
# 94    57   entrepreneur       divorced  secondary     no      -37
# 100   44    blue-collar        married  secondary     no     -674
# 112   56  self-employed        married    primary     no      -34
# 117   33     management         single   tertiary     no      -67
# ...

# %%
#add new column that includes balance range in dataframe
df['Balance Range'] = df.Balance.apply(balance_buckets)

# %%
#Segment into balance ranges 
df_balance = df.groupby(['Balance Range', 'Subscription1']).size().reset_index(name='Count')

df_balance['Subscription1'] = df_balance['Subscription1'].map({False: 'No', True: 'Yes'})

# Pivot the DataFrame to have Balance Range as rows and Subscribed status as columns
df_balance = df_balance.pivot(index='Balance Range', columns='Subscription1', values='Count').reset_index()

# %%
#Preview pivoted Dataframe
df_balance
# Out:
# Subscription1  Balance Range       No     Yes
# 0                  0 - -4999   3554.0   210.0
# 1                   0 - 4999  33960.0  4638.0
# 2              10000 - 14999    387.0    91.0
# 3              15000 - 19999    143.0    15.0
# 4              20000 - 24999     84.0    12.0
# 5              25000 - 29999     37.0     8.0
# 6              30000 - 34999      8.0     3.0
# 7                5000 - 9999   1712.0   306.0
# 8                 Over 35000     35.0     6.0
# 9               below - 5000      2.0     NaN

# %%
df['Education'].value_counts()
# Out:
# Education
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64

# %%
#Segment into Education  
df_education = df.groupby(['Education', 'Subscription1']).size().reset_index(name='Count')

df_education['Subscription1'] = df_education['Subscription1'].map({False: 'No', True: 'Yes'})

# Pivot the DataFrame to have Balance Range as rows and Subscribed status as columns
df_education = df_education.pivot(index='Education', columns='Subscription1', values='Count').reset_index()

# %%
#Preview pivoted Dataframe
df_education
# Out:
# Subscription1  Education     No   Yes
# 0                primary   6260   591
# 1              secondary  20752  2450
# 2               tertiary  11305  1996
# 3                unknown   1605   252

# %%
#Segment into Martial Status  
df_martial = df.groupby(['Marital Status', 'Subscription1']).size().reset_index(name='Count')

df_martial['Subscription1'] = df_martial['Subscription1'].map({False: 'No', True: 'Yes'})

# Pivot the DataFrame to have Balance Range as rows and Subscribed status as columns
df_martial = df_martial.pivot(index='Marital Status', columns='Subscription1', values='Count').reset_index()

# %%
#Preview pivoted Dataframe
df_martial
# Out:
# Subscription1 Marital Status     No   Yes
# 0                   divorced   4585   622
# 1                    married  24459  2755
# 2                     single  10878  1912

# %%
#Segment into housing loan  
df_housing = df.groupby(['Housing Loan', 'Subscription1']).size().reset_index(name='Count')

df_housing['Subscription1'] = df_housing['Subscription1'].map({False: 'No', True: 'Yes'})

# Pivot the DataFrame to have housing loan as rows and Subscribed status as columns
df_housing = df_housing.pivot(index='Housing Loan', columns='Subscription1', values='Count').reset_index()

# %%
#Preview pivoted Dataframe
df_housing
# Out:
# Subscription1 Housing Loan     No   Yes
# 0                       no  16727  3354
# 1                      yes  23195  1935

# %%
#Segment into personal loan  
df_personal = df.groupby(['Personal Loan', 'Subscription1']).size().reset_index(name='Count')

df_personal['Subscription1'] = df_personal['Subscription1'].map({False: 'No', True: 'Yes'})

# Pivot the DataFrame to have personal loan as rows and Subscribed status as columns
df_personal = df_personal.pivot(index='Personal Loan', columns='Subscription1', values='Count').reset_index()

# %%
#Preview pivoted Dataframe
df_personal
# Out:
# Subscription1 Personal Loan     No   Yes
# 0                        no  33162  4805
# 1                       yes   6760   484

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    45211 non-null  int64
#  1   Job                    45211 non-null  object
#  2   Marital Status         45211 non-null  object
#  3   Education              45211 non-null  object
#  4   Credit                 45211 non-null  object
#  5   Balance                45211 non-null  int64
#  6   Housing Loan           45211 non-null  object
#  7   Personal Loan          45211 non-null  object
#  8   Contact type           45211 non-null  object
#  9   Last Contact Day       45211 non-null  int64
#  10  Last Contact Month     45211 non-null  object
#  11  Last Contact Duration  45211 non-null  int64
#  12  Campaign Freq          45211 non-null  int64
#  13  Lag in days            45211 non-null  int64
# ...

# %%
df_age1.to_csv('Age.csv')

# %%
df_age1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age Range  8 non-null      object
#  1   No         8 non-null      int64
#  2   Yes        8 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 324.0+ bytes

# %%
df_age1
# Out:
# Subscription1 Age Range     No   Yes
# 0                 18-29   4345   928
# 1                 30-39  16176  1913
# 2                 40-49  10592  1063
# 3                 50-59   7625   785
# 4                 60-69    865   365
# 5                 70-79    244   180
# 6                 80-89     73    48
# 7               Over 90      2     7

# %%
df_age1['Conversion Rate'] = df_age1['Yes'] / (df_age1['No'] + df_age1['Yes'])*100

# %%
df_age1['Conversion Rate'] = round(df_age1['Conversion Rate'],2)

# %%
df_age1
# Out:
# Subscription1 Age Range     No   Yes  Conversion Rate
# 0                 18-29   4345   928            17.60
# 1                 30-39  16176  1913            10.58
# 2                 40-49  10592  1063             9.12
# 3                 50-59   7625   785             9.33
# 4                 60-69    865   365            29.67
# 5                 70-79    244   180            42.45
# 6                 80-89     73    48            39.67
# 7               Over 90      2     7            77.78

# %%
df_age1.to_csv('Age.csv')

# %%
#Calculate Conversion Rate on Job
df_job['Conversion Rate'] = df_job['Yes'] / (df_job['No'] + df_job['Yes'])*100
#Round the result to 2 decimal places
df_job['Conversion Rate'] = round(df_job['Conversion Rate'],2)

# %%
#view the results of conversion caluclation
df_job
# Out:
# Subscription1            Job    No   Yes  Conversion Rate
# 0                     admin.  4540   631            12.20
# 1                blue-collar  9024   708             7.27
# 2               entrepreneur  1364   123             8.27
# 3                  housemaid  1131   109             8.79
# 4                 management  8157  1301            13.76
# 5                    retired  1748   516            22.79
# 6              self-employed  1392   187            11.84
# 7                   services  3785   369             8.88
# 8                    student   669   269            28.68
# 9                 technician  6757   840            11.06
# 10                unemployed  1101   202            15.50
# 11                   unknown   254    34            11.81

# %%
df_job.to_csv('Job.csv')

# %%
#Calculate Conversion Rate on Balance
df_balance['Conversion Rate'] = df_balance['Yes'] / (df_balance['No'] + df_balance['Yes'])*100
#Round the result to 2 decimal places
df_balance['Conversion Rate'] = round(df_balance['Conversion Rate'],2)
#view results
df_balance
# Out:
# Subscription1  Balance Range       No     Yes  Conversion Rate
# 0                  0 - -4999   3554.0   210.0             5.58
# 1                   0 - 4999  33960.0  4638.0            12.02
# 2              10000 - 14999    387.0    91.0            19.04
# 3              15000 - 19999    143.0    15.0             9.49
# 4              20000 - 24999     84.0    12.0            12.50
# 5              25000 - 29999     37.0     8.0            17.78
# 6              30000 - 34999      8.0     3.0            27.27
# 7                5000 - 9999   1712.0   306.0            15.16
# 8                 Over 35000     35.0     6.0            14.63
# 9               below - 5000      2.0     NaN              NaN

# %%
df_balance.to_csv('Balance.csv')

# %%
#Calculate Conversion Rate on education
df_education['Conversion Rate'] = df_education['Yes'] / (df_education['No'] + df_education['Yes'])*100
#Round the result to 2 decimal places
df_education['Conversion Rate'] = round(df_education['Conversion Rate'],2)
#view results
df_education
# Out:
# Subscription1  Education     No   Yes  Conversion Rate
# 0                primary   6260   591             8.63
# 1              secondary  20752  2450            10.56
# 2               tertiary  11305  1996            15.01
# 3                unknown   1605   252            13.57

# %%
df_education.to_csv('Education.csv')

# %%
#Calculate Conversion Rate on martial status
df_martial['Conversion Rate'] = df_martial['Yes'] / (df_martial['No'] + df_martial['Yes'])*100
#Round the result to 2 decimal places
df_martial['Conversion Rate'] = round(df_martial['Conversion Rate'],2)
#view results
df_martial
# Out:
# Subscription1 Marital Status     No   Yes  Conversion Rate
# 0                   divorced   4585   622            11.95
# 1                    married  24459  2755            10.12
# 2                     single  10878  1912            14.95

# %%
df_martial.to_csv('Martial_csv')

# %%
#Calculate Conversion Rate on housing loan
df_housing['Conversion Rate'] = df_housing['Yes'] / (df_housing['No'] + df_housing['Yes'])*100
#Round the result to 2 decimal places
df_housing['Conversion Rate'] = round(df_housing['Conversion Rate'],2)
#view results
df_housing
# Out:
# Subscription1 Housing Loan     No   Yes  Conversion Rate
# 0                       no  16727  3354             16.7
# 1                      yes  23195  1935              7.7

# %%
df_housing.to_csv('Housing.csv')

# %%
#Calculate Conversion Rate on personal loan
df_personal['Conversion Rate'] = df_personal['Yes'] / (df_personal['No'] + df_personal['Yes'])*100
#Round the result to 2 decimal places
df_personal['Conversion Rate'] = round(df_personal['Conversion Rate'],2)
#view results
df_personal
# Out:
# Subscription1 Personal Loan     No   Yes  Conversion Rate
# 0                        no  33162  4805            12.66
# 1                       yes   6760   484             6.68

# %%
#Save personal loan df as csv
df_personal.to_csv('Personal.csv')

# %%
df.to_csv('Segmentation.csv')

# %%
data = pd.read_csv('direct_marketing_dataset.csv')

# %%
direct = pd.read_csv('Direct_Marketing_Campaign.csv')

# %%
direct
# Out:
#        Age           Job Marital Status  Education Credit  Balance  \
# 0       58    management        married   tertiary     no     2143
# 1       44    technician         single  secondary     no       29
# 2       33  entrepreneur        married  secondary     no        2
# 3       47   blue-collar        married    unknown     no     1506
# 4       33       unknown         single    unknown     no        1
# ...    ...           ...            ...        ...    ...      ...
# 45206   51    technician        married   tertiary     no      825
# 45207   71       retired       divorced    primary     no     1729
# 45208   72       retired        married  secondary     no     5715
# 45209   57   blue-collar        married  secondary     no      668
# 45210   37  entrepreneur        married  secondary     no     2971
#
#       Housing Loan Personal Loan Contact type  Last Contact Day  \
# 0              yes            no      unknown                 5
# ...

# %%
#add new column that includes balance range in dataframe
direct['Balance Range'] = df.Balance.apply(balance_buckets)

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Identifying numeric and categorical columns
numeric_features = ['Age', 'Balance', 'Last Contact Duration', 'Campaign Freq', 'Lag in days', 'Previous Freq']
categorical_features = ['Job', 'Marital Status', 'Education', 'Credit', 'Housing Loan', 'Personal Loan', 'Contact type', 'Last Contact Day', 'Last Contact Month', 'Previous outcome']

# Creating transformers for preprocessing
numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# Combining transformers into a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Applying the preprocessing to the dataset
X_preprocessed = preprocessor.fit_transform(direct)

X_preprocessed.shape
# Out:
# (45211, 81)

# %%
from sklearn.cluster import KMeans
import numpy as np

# Function to calculate the sum of squared distances for different numbers of clusters
def calculate_wcss(data):
    wcss = []
    for n in range(1, 11):
        kmeans = KMeans(n_clusters=n, init='k-means++', max_iter=300, n_init=10, random_state=0)
        kmeans.fit(data)
        wcss.append(kmeans.inertia_)
    return wcss

# Calculate WCSS for different numbers of clusters
wcss = calculate_wcss(X_preprocessed)

# Plotting the results on a line graph to observe the 'Elbow'
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.title('Elbow Method For Optimal Number of Clusters')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Applying K-means clustering with 4 clusters
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0)
kmeans.fit(X_preprocessed)

# Assigning the clusters to each instance in the dataset
cluster_labels = kmeans.labels_

# Adding the cluster labels to the original dataset for interpretation
direct['Cluster'] = cluster_labels

# Displaying the first few rows of the dataframe with cluster labels
direct.head()
# Out:
#    Age           Job Marital Status  Education Credit  Balance Housing Loan  \
# 0   58    management        married   tertiary     no     2143          yes
# 1   44    technician         single  secondary     no       29          yes
# 2   33  entrepreneur        married  secondary     no        2          yes
# 3   47   blue-collar        married    unknown     no     1506          yes
# 4   33       unknown         single    unknown     no        1           no
#
#   Personal Loan Contact type  Last Contact Day Last Contact Month  \
# 0            no      unknown                 5                may
# 1            no      unknown                 5                may
# 2           yes      unknown                 5                may
# 3            no      unknown                 5                may
# 4            no      unknown                 5                may
#
#    Last Contact Duration  Campaign Freq  Lag in days  Previous Freq  \
# ...

# %%
# Analyzing the distribution of features within each cluster

# Numeric features analysis: Calculating mean values within each cluster
numeric_summary = direct.groupby('Cluster')[numeric_features].mean()

# Categorical features analysis: Calculating the most common category within each cluster
categorical_summary = direct.groupby('Cluster')[categorical_features].agg(pd.Series.mode)

# Displaying summary for numeric features
print("Numeric Features Summary by Cluster:")
display(numeric_summary)

# Because mode could return multiple values if there's a tie, we simplify the display for readability
print("\nCategorical Features Summary by Cluster (Showing one mode per feature):")
for feature in categorical_features:
    print(f"\nFeature: {feature}")
    display(categorical_summary[feature].apply(lambda x: x[0] if isinstance(x, list) else x))
# Out:
# Numeric Features Summary by Cluster:
#                Age      Balance  Last Contact Duration  Campaign Freq  \
# Cluster
# 0        40.293973  1084.094711             152.659902      14.868389
# 1        34.164412   932.063704             274.310187       2.283218
# 2        39.585071  1426.636560             256.383144       2.092910
# 3        52.228931  2033.683718             245.828232       2.464151
#
#          Lag in days  Previous Freq
# Cluster
# 0          -0.150677       0.021525
# 1           0.776409       0.038885
# 2         248.942183       3.416367
# 3           4.849965       0.110412
# Categorical Features Summary by Cluster (Showing one mode per feature):
#
# Feature: Job
# Cluster
# 0     management
# 1    blue-collar
# 2    blue-collar
# 3     management
# Name: Job, dtype: object
# Feature: Marital Status
# Cluster
# 0    married
# 1    married
# 2    married
# 3    married
# Name: Marital Status, dtype: object
# Feature: Education
# Cluster
# 0    secondary
# ...

# %%
# convert subscription into a boolean 1(No) 2 (Yes)
direct['Subscription'] = direct['Subscription'].map({1:False, 2: True})

direct['Subscription'] = direct['Subscription'].map({False: 'No', True: 'Yes'})

# %%
direct
# Out:
#        Age           Job Marital Status  Education Credit  Balance  \
# 0       58    management        married   tertiary     no     2143
# 1       44    technician         single  secondary     no       29
# 2       33  entrepreneur        married  secondary     no        2
# 3       47   blue-collar        married    unknown     no     1506
# 4       33       unknown         single    unknown     no        1
# ...    ...           ...            ...        ...    ...      ...
# 45206   51    technician        married   tertiary     no      825
# 45207   71       retired       divorced    primary     no     1729
# 45208   72       retired        married  secondary     no     5715
# 45209   57   blue-collar        married  secondary     no      668
# 45210   37  entrepreneur        married  secondary     no     2971
#
#       Housing Loan Personal Loan Contact type  Last Contact Day  \
# 0              yes            no      unknown                 5
# ...

# %%
directsub = direct[direct['Subscription'] == 'Yes']

# %%
directsub['Age'].mean()
# Out:
# 41.670069956513515

# %%
direct.hist(bins = 50, figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Balance'}>,
#         <Axes: title={'center': 'Last Contact Day'}>],
#        [<Axes: title={'center': 'Last Contact Duration'}>,
#         <Axes: title={'center': 'Campaign Freq'}>,
#         <Axes: title={'center': 'Lag in days'}>],
#        [<Axes: title={'center': 'Previous Freq'}>,
#         <Axes: title={'center': 'Cluster'}>, <Axes: >]], dtype=object)

# %%
direct0 = direct[direct['Cluster'] == 0]

# %%
direct1 = direct[direct['Cluster'] == 1]

# %%
direct2 = direct[direct['Cluster'] == 2]

# %%
direct3 = direct[direct['Cluster'] == 3]

# %%
direct0
# Out:
#        Age            Job Marital Status  Education Credit  Balance  \
# 1483    34     management        married   tertiary     no       76
# 1502    35  self-employed         single   tertiary     no      538
# 1626    34       services        married  secondary     no      627
# 2244    46    blue-collar        married    primary     no      633
# 2251    40     technician        married  secondary     no     2576
# ...    ...            ...            ...        ...    ...      ...
# 42948   36     management        married   tertiary     no     1257
# 43546   41         admin.       divorced  secondary     no     3823
# 44180   30         admin.        married  secondary     no      222
# 44231   32   entrepreneur        married   tertiary     no      762
# 44594   34     technician         single   tertiary     no     2481
#
#       Housing Loan Personal Loan Contact type  Last Contact Day  \
# 1483            no            no      unknown                 8
# ...

# %%
direct0['Subscription'].value_counts()
# Out:
# Subscription
# No     1573
# Yes      53
# Name: count, dtype: int64

# %%
direct1['Subscription'].value_counts()
# Out:
# Subscription
# No     20009
# Yes     2313
# Name: count, dtype: int64

# %%
direct2['Subscription'].value_counts()
# Out:
# Subscription
# No     5565
# Yes    1388
# Name: count, dtype: int64

# %%
direct3['Subscription'].value_counts()
# Out:
# Subscription
# No     12775
# Yes     1535
# Name: count, dtype: int64

# %%
direct0['Job'].value_counts()
# Out:
# Job
# management       378
# blue-collar      351
# technician       318
# admin.           171
# services         144
# self-employed     64
# entrepreneur      60
# housemaid         40
# retired           32
# unemployed        31
# unknown           21
# student           16
# Name: count, dtype: int64

# %%
direct.to_csv('clusters_segment3.csv')

# %%
import matplotlib.pyplot as plt
#from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
direct['Age Range'] = direct.Age.apply(age_buckets)

# %%
direct['Age Range'].value_counts()
# Out:
# Age Range
# 30-39      18089
# 40-49      11655
# 50-59       8410
# 18-29       5273
# 60-69       1230
# 70-79        424
# 80-89        121
# Over 90        9
# Name: count, dtype: int64

# %%
direct['Balance Range'].value_counts()
# Out:
# Balance Range
# 0 - 4999         38598
# 0 - -4999         3764
# 5000 - 9999       2018
# 10000 - 14999      478
# 15000 - 19999      158
# 20000 - 24999       96
# 25000 - 29999       45
# Over 35000          41
# 30000 - 34999       11
# below - 5000         2
# Name: count, dtype: int64

# %%
direct.to_csv('cluster_segments1.csv')

# %%
direct
# Out:
#        Age           Job Marital Status  Education Credit  Balance  \
# 0       58    management        married   tertiary     no     2143
# 1       44    technician         single  secondary     no       29
# 2       33  entrepreneur        married  secondary     no        2
# 3       47   blue-collar        married    unknown     no     1506
# 4       33       unknown         single    unknown     no        1
# ...    ...           ...            ...        ...    ...      ...
# 45206   51    technician        married   tertiary     no      825
# 45207   71       retired       divorced    primary     no     1729
# 45208   72       retired        married  secondary     no     5715
# 45209   57   blue-collar        married  secondary     no      668
# 45210   37  entrepreneur        married  secondary     no     2971
#
#       Housing Loan Personal Loan Contact type  Last Contact Day  \
# 0              yes            no      unknown                 5
# ...

# %%
direct['Age Range'] = df.Age.apply(age_buckets)

# %%
direct
# Out:
#        Age           Job Marital Status  Education Credit  Balance  \
# 0       58    management        married   tertiary     no     2143
# 1       44    technician         single  secondary     no       29
# 2       33  entrepreneur        married  secondary     no        2
# 3       47   blue-collar        married    unknown     no     1506
# 4       33       unknown         single    unknown     no        1
# ...    ...           ...            ...        ...    ...      ...
# 45206   51    technician        married   tertiary     no      825
# 45207   71       retired       divorced    primary     no     1729
# 45208   72       retired        married  secondary     no     5715
# 45209   57   blue-collar        married  secondary     no      668
# 45210   37  entrepreneur        married  secondary     no     2971
#
#       Housing Loan Personal Loan Contact type  Last Contact Day  \
# 0              yes            no      unknown                 5
# ...

# %%
direct.to_csv('Last attempt.csv')

# %%
# categories customers based on balance
def balance_buckets1(x):
    if x < -5000:
        return 'below - 5000'
    elif x < 0:
        return '0 - -4999'
    elif x < 3000: 
        return '0 - 2999' 
    elif x < 6000: 
        return '3000 - 5999' 
    elif x < 9000: 
        return '6000 - 8999' 
    elif x < 12000: 
        return '9000 - 11,999' 
    elif x < 15000: 
        return '12,000 - 14,999' 
    elif x < 18000: 
        return '15,000 - 17,999'
    elif x < 21000:
        return '18,000 - 20,999'
    elif x < 24000:
        return '21,000 - 23,999'
    elif x < 27000:
        return '24,000 - 26,999'
    elif x < 30000:
        return '27,000 - 29,999'
    else: 
        return 'Over 30,000'

# %%
#add new column that includes balance range in dataframe
direct['Balance Range'] = df.Balance.apply(balance_buckets1)

# %%
direct1 = direct

# %%
direct1
# Out:
#        Age           Job Marital Status  Education Credit  Balance  \
# 0       58    management        married   tertiary     no     2143
# 1       44    technician         single  secondary     no       29
# 2       33  entrepreneur        married  secondary     no        2
# 3       47   blue-collar        married    unknown     no     1506
# 4       33       unknown         single    unknown     no        1
# ...    ...           ...            ...        ...    ...      ...
# 45206   51    technician        married   tertiary     no      825
# 45207   71       retired       divorced    primary     no     1729
# 45208   72       retired        married  secondary     no     5715
# 45209   57   blue-collar        married  secondary     no      668
# 45210   37  entrepreneur        married  secondary     no     2971
#
#       Housing Loan Personal Loan Contact type  Last Contact Day  \
# 0              yes            no      unknown                 5
# ...

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Identifying numeric and categorical columns
numeric_features = ['Age', 'Balance', 'Last Contact Duration', 'Campaign Freq', 'Lag in days', 'Previous Freq']
categorical_features = ['Job', 'Marital Status', 'Education', 'Credit', 'Housing Loan', 'Personal Loan', 'Contact type', 'Last Contact Day', 'Last Contact Month', 'Previous outcome']

# Creating transformers for preprocessing
numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# Combining transformers into a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Applying the preprocessing to the dataset
X_preprocessed = preprocessor.fit_transform(direct)

X_preprocessed.shape
# Out:
# (45211, 81)

# %%
# Applying K-means clustering with 4 clusters
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0)
kmeans.fit(X_preprocessed)

# Assigning the clusters to each instance in the dataset
cluster_labels = kmeans.labels_

# Adding the cluster labels to the original dataset for interpretation
direct['Cluster'] = cluster_labels

# Displaying the first few rows of the dataframe with cluster labels
direct.head()
# Out:
#    Age           Job Marital Status  Education Credit  Balance Housing Loan  \
# 0   58    management        married   tertiary     no     2143          yes
# 1   44    technician         single  secondary     no       29          yes
# 2   33  entrepreneur        married  secondary     no        2          yes
# 3   47   blue-collar        married    unknown     no     1506          yes
# 4   33       unknown         single    unknown     no        1           no
#
#   Personal Loan Contact type  Last Contact Day Last Contact Month  \
# 0            no      unknown                 5                may
# 1            no      unknown                 5                may
# 2           yes      unknown                 5                may
# 3            no      unknown                 5                may
# 4            no      unknown                 5                may
#
#    Last Contact Duration  Campaign Freq  Lag in days  Previous Freq  \
# ...
